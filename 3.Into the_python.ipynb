# %% [markdown]
# # here we r learning about :
#
# 1. keywords
# 2. identifiers
# 3. Variables, Constants, Literals
# 4. Datatypes & type conversions
# 5. Operators
# 6. Comments

# %% [markdown]
# ![pic](images\img6.png)

# %% [markdown]
# # 1.keywods:
# * Keywords are predefined, reserved words used in Python Prograamming
# * we cannot use a keywords as a variable name , function name , or any other identifier
# * we have currently 35 keywords
# * these are already fixed by creators of python researchers, so below names should not use for variable , function etc
#
# ![pic](images\img7.png)

# %% [markdown]
# # 2.Identifiers:
# * thesea are the name given to variables, classes, methods etc
#
# ![pic1](images\img8.png)
#
# ![pic2](images\img9.png)
#
# ![pic3](images\img10.png)
#
# * An identifier should start with this below only:
#
# ![pic4](images\img11.png)

# %% [markdown]
# # 3. Variables
# * In programming , a variables is a container (storage area) to hold data
#
# ![pic1](images\img12.png)
#
# # 3.1 Constants:
# * A constant is a special type of variable whose value cannot be changed
#
# ![image.png](attachment:image.png)
#
# # 3.2 Literals:
# * Literals are representations of fixed values in a program They can be numbers, characters, or strings, etc.

# %% [markdown]
# # Imp : Variables VS Identifiers
#
# * Identifiders are names given to entities like variables, functions, etc . while variables are a specific type of identifier used to store and manipulate data in a program

# %% [markdown]
# # 4.Datatypes:
#
#
# 1. Text Data Type:
# - string :
# * str represents strings of characters , enclosed in single , doible , or triple quotes .
# * eg :
# \
# 'hello' ,
# "hello" ,
# '''hello'''
#
# 2. Numeric data types:
# - int :
# * Represents integer values
# * (eg : 1,-10,100)
# * it has fixed storage 4 bytes
# * for long int it will be 8 bytes
#
# - float:
# * Represents floatin point or decimal vlaues
# eg (3.14 , -2.5)
#
# - complex :
# complex values (eg : 3.14j , 1-2i)
#
# ![image-3.png](attachment:image-3.png)
#
# 3. sequence Data Types:
#
# ![image-2.png](attachment:image-2.png)
#
# 4. Mapping Data types:
#
# ![image-4.png](attachment:image-4.png)
#
# 5. Boolean Data types:
#
# ![image-5.png](attachment:image-5.png)
#
# 6. None Data types:
#
# ![image-6.png](attachment:image-6.png)
#
#
#
#
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 4.1 Type Conversions
#
# * in Prgramming type conversion is the process of converting data of one type to anohter
# * for ex : converting int data to str

# %%
a = 100
b = 1.5
c = a+b

print(type(100))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = 100
a = float(a)
print(type(a))

#here int conveting int to float

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![img-4.png](images\img24.png)

# %% [markdown]
# # Introduction to ASCII Values
#
# * the "ASCII Value" of a character is a number that represents that character in the computers memory
#
# ![pic1](images\img25.png)

# %%
a = 66

ascii = chr(a)

print(ascii)
# Out:
# B

# %% [markdown]
# # 5.Operators
#
# * we have :
# 1. Arthimetic Operators
# 2. Assignment Operators
# 3. Comparision Operators
# 4. Logical Operators
# 5. Bitwise Operators
# 6. Special Operators
#
# * --------------
# 1. Arthimetic Operators :
# ![pic1](images\img26.png)
# ![pic2](images\img27.png)
# ![pic3](images\img28.png)
# ![pic4](images\img29.png)

# %%
a = 10
b = 20
c = a+b

print(c)
# Out:
# 30

# %% [markdown]
# 2. floo

# %% [markdown]
# 2. Assinment operators:
#
# ![pic1](images\img30.png)
#
# ![pic2](images\img31.png)
#
# ![p](images\img32.png)
#
# ![p](images\img33.png)

# %% [markdown]
# 3. Comparision operators :
#
# ![p](images\img34.png)
#
# ![p](images\img35.png)
#
# ![p](images\img36.png)

# %% [markdown]
# 4. Logical Operators:
#
# ![p](images\img37.png)
#
# ![p](images\img38.png)
#
# ![p](images\img39.png)
#
# ![p](images\img40.png)

# %% [markdown]
# 5. Bitwise Operators:
#
# ![p](images\img41.png)
#
# ![p](images\img42.png)
#
# ![p](images\img43.png)
#
# 6. Operator Precedure:
#
# ![p](images\img44.png)
#
# ![p](images\img45.png)

# %% [markdown]
# # 6. Comments:
#
# 1. single line comments:
# * these are begin with a # symbol and continue until the end of the line
#
# 2. multiline comments:
# * Docstrings are enclosed in triple quotes (''' or """) and can span multiple lines.
